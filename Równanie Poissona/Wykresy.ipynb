# %%
import matplotlib.pyplot as plt
import numpy as np

ścieżka = "C:\studeia\SemestrKochany\\" # w razie potrzeby zmienić ścieżkę

def kolorowy_wykres(u,tytul="Nie sprecyzowana nazwa wykresu"):
    rows = np.linspace(-30,30,num=len(u)).astype(int)
    #Levels = np.linspace(np.min(u)*1.01,np.amax(u)*1.01)
    columns = np.linspace(-30,30,num=len(u[0])).astype(int)
    plt.contourf(rows,columns,u,levels=50)
    plt.colorbar()
    plt.xlabel("Odległość na osi x")
    plt.ylabel("Odległość na osi y")
    plt.title(tytul)
    return

def readFile(plik,rzmr):
    charsy = open(plik,'r').read().split('\n')
    retVar = np.zeros((2*N-1,2*N-1))
    for i in range(2*N-1):
        retVar[i] = np.fromstring(charsy[i],float,sep = ' ')
    return retVar

# %%
N = int(open(ścieżka+"Nka.txt",'r').read())
Upo100 = readFile(ścieżka+"Po100Iteracjach.txt",N)
Upo500 = readFile(ścieżka+"Po500Iteracjach.txt",N)
a = np.fromstring(open(ścieżka+"ADlaWR1.txt",'r').read(),float,sep = ' ')
roPrim = readFile(ścieżka+"roPrim1.txt",N)
delta = readFile(ścieżka+"delta1.txt",N)

# %%
kolorowy_wykres(Upo100,"Potencjał po 100 iteracjach dla w=1")

# %%
kolorowy_wykres(Upo500,"Potencjał po 500 iteracjach dla w=1")

# %%
plt.plot(a)
plt.title("Wykres lagrangianu (a) w zależności od iteracji")
# Out:
# Text(0.5, 1.0, 'Wykres lagrangianu (a) w zależności od iteracji')

# %%
kolorowy_wykres(delta,"Różnica między ro a ro prim")

# %%
kolorowy_wykres(roPrim,"Uzyskana ponownie z modelu wartość ro (rhoPrim)")

# %%
Upo100 = readFile(ścieżka+"Po100IteracjachP2.txt",N)
Upo500 = readFile(ścieżka+"Po500IteracjachP2.txt",N)
a = np.fromstring(open(ścieżka+"ADlaWR2.txt",'r').read(),float,sep = ' ')
roPrim = readFile(ścieżka+"roPrim2.txt",N)
delta = readFile(ścieżka+"delta2.txt",N)

# %%
kolorowy_wykres(Upo100,"Potencjał po 100 iteracjach dla w=1.9")

# %%
kolorowy_wykres(Upo500,"Potencjał po 500 iteracjach dla w=1.9")

# %%
plt.plot(a)

# %%
kolorowy_wykres(delta,"Różnica między ro a ro prim")

# %%
#zadanie 3
Upo100 = readFile(ścieżka+"Po100IteracjachP3.txt",N)
Upo500 = readFile(ścieżka+"Po500IteracjachP3.txt",N)
a = np.fromstring(open(ścieżka+"ADlaWR3.txt",'r').read(),float,sep = ' ')
roPrim = readFile(ścieżka+"roPrim3.txt",N)
delta = readFile(ścieżka+"delta3.txt",N)

# %%
kolorowy_wykres(Upo100,"Potencjał po 100 iteracjach dla minimalizacji a")

# %%
kolorowy_wykres(Upo500,"Potencjał po 500 iteracjach dla w=1.9")

# %%
plt.plot(a)

# %%
kolorowy_wykres(delta,"Różnica między ro a ro prim")
